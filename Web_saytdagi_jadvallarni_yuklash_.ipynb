# %% [markdown]
# <a href="https://colab.research.google.com/github/MUHAMMADALIBOBOKHON2003/mening_darslarim/blob/main/Web_saytdagi_jadvallarni_yuklash_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # WEB SAYTDAN JADVALLARNI YUKLASH

# %%
import numpy as np
import pandas as pd

# %%
# agar web saytdagi barcha jadvallarni oqimoqchi bo'lsak quyida vazifalarni bajaramiz
webdf=pd.read_html("https://ru.wikipedia.org/wiki/%D0%A2%D0%B0%D1%88%D0%BA%D0%B5%D0%BD%D1%82")
webdf
# Out:
# [                                                    0  \
#  0                                               Город
#  1                                             Ташкент
#  2                              узб. Toshkent, Тошкент
#  3   По часовой стрелке сверху: панорама Ташкента, ...
#  4                                                 NaN
#  5                                                 NaN
#  6                                                 NaN
#  7                                                 NaN
#  8                                                 NaN
#  9                                           Флаг Герб
#  10                                                NaN
#  11                                               Флаг
#  12                      41°18′ с. ш. 69°15′ в. д.HGЯO
#  13                                             Страна
#  14                                             Статус
#  15                                 Внутреннее деление
# ...

# %%
# nechta jadval borligini bilish
len (webdf)
# Out:
# 22

# %%
# webdf ning ichidagi df larni huddi ro'yhat bilan ishlagandek chaqirib olishimiz mumkin
webdf[5] # ko'rishingiz mumkin 5 indexda turgan df ni chiqardi
# Out:
#        Год  узбеки  русские  татары  казахи  евреи  прочие
# 0  1868 г.     748       21       6       3      2       1
# 1  1897 г.    1284      176      23      19     14      40
# 2  1910 г.    1688      474      19      11     36     114

# %%
webdf[20]
# Out:
#         Узбекистан в темах                               Узбекистан в темах.1  \
# 0  Государственные символы                                     Флаг Герб Гимн
# 1    Государственный строй  Гражданин Конституция Президент Правительство ...
# 2                География  Столица Геология Минеральные ресурсы Рельеф Кл...
# 3                  История                             Предыстория СССР/УзССР
# 4                Экономика  Валюта Давлат белгиси Промышленность Сельское ...
# 5         Вооружённые силы  Сухопутные войска Войска ПВО и ВВС Специальные...
# 6                Население                        Города Этносы Языки Религия
# 7                 Культура  Наука Образование Литература Архитектура Музык...
# 8                    Спорт  Автоспорт Альпинизм Баскетбол Волейбол Гимнаст...
# 9  Категория Портал Проект                            Категория Портал Проект
#
#       Узбекистан в темах.2
# 0                      NaN
# 1                      NaN
# ...

# %% [markdown]
# # agar bizga ichidan qandaydir df kerak bo'lsa unda har bitta indexni berib chiqish kerak

# %% [markdown]
# # TAKRORLASH

# %%
russia=pd.read_html("https://en.wikipedia.org/wiki/Russia")
russia
# Out:
# [               Russian FederationРоссийская Федерация  \
#  0                                  Flag  Coat of arms
#  1   Anthem: Государственный гимн Российской Федера...
#  2   Russia on the globe, with the disputed Kuril I...
#  3                             Capitaland largest city
#  4   Official.mw-parser-output .nobold{font-weight:...
#  5                       Recognised national languages
#  6                             Ethnic groups (2010)[4]
#  7                                  Religion (2012)[5]
#  8                                          Demonym(s)
#  9                                          Government
#  10                                                NaN
#  11                                        • President
#  12                                   • Prime Minister
#  13                 • Speaker of theFederation Council
#  14                         • Speaker of theState Duma
#  15                                    • Chief Justice
# ...

# %%
# russiya wikisida nechta df borligini ko'rish
len (russia)
# Out:
# 21

# %%
russia[0]
# Out:
#                Russian FederationРоссийская Федерация  \
# 0                                  Flag  Coat of arms
# 1   Anthem: Государственный гимн Российской Федера...
# 2   Russia on the globe, with the disputed Kuril I...
# 3                             Capitaland largest city
# 4   Official.mw-parser-output .nobold{font-weight:...
# 5                       Recognised national languages
# 6                             Ethnic groups (2010)[4]
# 7                                  Religion (2012)[5]
# 8                                          Demonym(s)
# 9                                          Government
# 10                                                NaN
# 11                                        • President
# 12                                   • Prime Minister
# 13                 • Speaker of theFederation Council
# 14                         • Speaker of theState Duma
# 15                                    • Chief Justice
# ...

# %%
russia[6]
# Out:
#                                                    0  \
# 0  Civil Service Conscription Constitution Electi...
#
#                                                    1
# 0  Civil Service Conscription Constitution Electi...
