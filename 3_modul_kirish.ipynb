# %% [markdown]
# <a href="https://colab.research.google.com/github/MUHAMMADALIBOBOKHON2003/mening_darslarim/blob/main/3_modul_kirish.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # githubdan faylni yuklash

# %%
! wget https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/Salary_Data.csv
# Out:
# --2022-10-19 12:50:23--  https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/Salary_Data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 423 [text/plain]
# Saving to: ‘Salary_Data.csv’
#
# Salary_Data.csv     100%[===================>]     423  --.-KB/s    in 0s
#
# 2022-10-19 12:50:23 (25.8 MB/s) - ‘Salary_Data.csv’ saved [423/423]

# %%
# yuqorida ko'rishingiz mumkin faylni yuklab oldik. Agar colbdan chiqib ketsak fayl o'chadi, buning oldini olish uchun "diskni yoqish" funksiyasidan foydalanamiz
#Lekin agar chiqib ketsak yoki 12 soatdan ortiq colabda ishlasak faylimiz o'chadi

# %%
# git clone githubdan faylni yuklab olish uchun ishlatiladi
# !git clone https://github.com/anvarnarz/praktikum_datasets
# Out:
# fatal: destination path 'praktikum_datasets' already exists and is not an empty directory.

# %%
# papkamiz colabga yuklandi

# %% [markdown]
# # fayllarni DataFrame ko'rinishda ochish

# %%
# fayllarni o'qish pandas kutubxonasiga tegishli bo'lgani uchun pd dan foylanamiz
import pandas as pd
import numpy as np

# %%
# agar kerakli fayl hech qaysi papkada joylashmagan bo'lsa nomini o'zini va formatini berish kifoya
df=pd.read_csv("Salary_Data.csv")
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
# agar kerakli faylni qandaydir papkani ichida bo'lsa faylgacha bo'lgan yo'lni ko'rsatish kerak
df2=pd.read_csv("praktikum_datasets/automobile_data.csv")
df2.head()
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0

# %%
# brauzerdan fayllarni silkasini ko'chirib olib ishlatishimiz ham mumkin
df_bra=pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/Salary_Data.csv')
df_bra
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
# biz faylni ochganimizda indexni colabni o'zi beryapti biz indexni o'zimiz tanlashimiz mumkin
# keling exel formatidagi faylni ochamiz
# ustunlarni nomini o'zgartirsak ham bo'ladi uning uchun names=[] dan foydalanamiz
df_xlsx=pd.read_excel("praktikum_datasets/E-Commerce-Dataset.xlsx", index_col=1,names=["nomsiz ma'l.","ma'lumot","funksiyalar 1","funksiyalar 2"]) 
# biz bu yerda Unnamed: 1 ni oldik Unnamed: 0 nan qiymatlarga ega bo'lgani uchun

df_xlsx.drop(["Data"]) # Data qatorini tashlash kerak ekan
# Out:
#           nomsiz ma'l.                funksiyalar 1  \
# ma'lumot
# E Comm             NaN                   CustomerID
# E Comm             NaN                        Churn
# E Comm             NaN                       Tenure
# E Comm             NaN         PreferredLoginDevice
# E Comm             NaN                     CityTier
# E Comm             NaN              WarehouseToHome
# E Comm             NaN         PreferredPaymentMode
# E Comm             NaN                       Gender
# E Comm             NaN               HourSpendOnApp
# E Comm             NaN     NumberOfDeviceRegistered
# E Comm             NaN             PreferedOrderCat
# E Comm             NaN            SatisfactionScore
# E Comm             NaN                MaritalStatus
# E Comm             NaN              NumberOfAddress
# E Comm             NaN                     Complain
# E Comm             NaN  OrderAmountHikeFromlastYear
# E Comm             NaN                   CouponUsed
# ...

# %%
# CSV fayllar nuqta-vergul bilan ajratilgan bo'lsa biz uni aytib o'tishimiz kerak sep=";" operatori yordamida
df_csv=pd.read_csv("praktikum_datasets/automobile_data.csv",sep=";")
df_csv
# Out:
#    index,company,body-style,wheel-base,length,engine-type,num-of-cylinders,horsepower,average-mileage,price
# 0   0,alfa-romero,convertible,88.6,168.8,dohc,four...
# 1   1,alfa-romero,convertible,88.6,168.8,dohc,four...
# 2   2,alfa-romero,hatchback,94.5,171.2,ohcv,six,15...
# 3       3,audi,sedan,99.8,176.6,ohc,four,102,24,13950
# 4       4,audi,sedan,99.4,176.6,ohc,five,115,18,17450
# ..                                                ...
# 56  81,volkswagen,sedan,97.3,171.7,ohc,four,85,27,...
# 57  82,volkswagen,sedan,97.3,171.7,ohc,four,52,37,...
# 58  86,volkswagen,sedan,97.3,171.7,ohc,four,100,26...
# 59   87,volvo,sedan,104.3,188.8,ohc,four,114,23,12940
# 60   88,volvo,wagon,104.3,188.8,ohc,four,114,23,13415
#
# [61 rows x 1 columns]

# %%
# yuqoridagi ko'dni sep=";" ni olib tashlasak chiroyliroq bo'lar ekan
# nrows=  degan parametr ham bor. nrows  qatorlar soni degani. Ya'ni qatolar sonini bersak ham bo'ladi
df_csv=pd.read_csv("praktikum_datasets/automobile_data.csv",nrows=19) # boshidan 19 ta qatorni chiqar dedik
df_csv
# qaytgan jadvalga ahamiyat bersangiz pd index bergan lekin jadvalning o'zida ham index bor shuni index_col="index" deb nomini berib yozsa ham bo'ladi
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# 5       5         audi        sedan        99.8   177.3         ohc
# 6       6         audi        wagon       105.8   192.7         ohc
# 7       9          bmw        sedan       101.2   176.8         ohc
# 8      10          bmw        sedan       101.2   176.8         ohc
# 9      11          bmw        sedan       101.2   176.8         ohc
# 10     13          bmw        sedan       103.5   189.0         ohc
# 11     14          bmw        sedan       103.5   193.8         ohc
# 12     15          bmw        sedan       110.0   197.0         ohc
# ...

# %%
# brauzerdan faylni yuklab olish
# !wget https://raw.githubusercontent.com/anvarnarz/python-darslar/main/00-jupyter/08-lists-tuples.ipynb
# Out:
# --2022-10-19 12:50:25--  https://raw.githubusercontent.com/anvarnarz/python-darslar/main/00-jupyter/08-lists-tuples.ipynb
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28528 (28K) [text/plain]
# Saving to: ‘08-lists-tuples.ipynb’
#
# 08-lists-tuples.ipy 100%[===================>]  27.86K  --.-KB/s    in 0.003s
#
# 2022-10-19 12:50:26 (8.97 MB/s) - ‘08-lists-tuples.ipynb’ saved [28528/28528]

# %%
df44=pd.read_csv("Salary_Data.csv",names=["Tajriba","Maosh"],nrows=6)
df44
# Out:
#            Tajriba     Maosh
# 0  YearsExperience    Salary
# 1              1.1  39343.00
# 2              1.3  46205.00
# 3              1.5  37731.00
# 4              2.0  43525.00
# 5              2.2  39891.00

# %%
# githubdan papka yuklashni ko'ramiz
# !git clone https://github.com/MUHAMMADALIBOBOKHON2003/mening_darslarim
# Out:
# Cloning into 'mening_darslarim'...
# remote: Enumerating objects: 138, done.
# remote: Counting objects: 100% (138/138), done.
# remote: Compressing objects: 100% (126/126), done.
# remote: Total 138 (delta 110), reused 16 (delta 7), pack-reused 0
# Receiving objects: 100% (138/138), 678.36 KiB | 3.67 MiB/s, done.
# Resolving deltas: 100% (110/110), done.

# %%
# ko'rishingiz mumkin kerakli papkani ya'ni repozitoriyni yuklab oldim

# %%
# kerakli faylni ko'chirib olish
# !wget https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/MOCK_USER_DATA.csv
# Out:
# --2022-10-19 12:50:27--  https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/MOCK_USER_DATA.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5356 (5.2K) [text/plain]
# Saving to: ‘MOCK_USER_DATA.csv’
#
# MOCK_USER_DATA.csv  100%[===================>]   5.23K  --.-KB/s    in 0s
#
# 2022-10-19 12:50:27 (73.7 MB/s) - ‘MOCK_USER_DATA.csv’ saved [5356/5356]

# %%
df33=pd.read_csv("MOCK_USER_DATA.csv",index_col=0,names=["Ism","Familiya","email","jinsi",'yoshi'])
df33
# Out:
#             Ism    Familiya                           email        jinsi yoshi
# id   first_name   last_name                           email       gender   age
# 1       Dorothy     Verryan               dverryan0@who.int   Non-binary     1
# 2       Pietrek     Scanlin          pscanlin1@yolasite.com         Male    91
# 3        Lilith    Sarjeant  lsarjeant2@creativecommons.org  Genderfluid  1233
# 4          Knox  Cunningham    kcunningham3@yellowpages.com  Genderfluid     6
# ..          ...         ...                             ...          ...   ...
# 96         Baxy       Marcu        bmarcu2n@list-manage.com      Agender    64
# 97       Kattie     Claxson          kclaxson2o@booking.com       Female    18
# 98         Clem     Fullerd  cfullerd2p@creativecommons.org     Bigender    55
# 99    Desdemona     Jurasek        djurasek2q@aboutads.info  Genderfluid    46
# 100       Mable     Toffano          mtoffano2r@myspace.com     Bigender   233
#
# [101 rows x 5 columns]

# %%
# brauzerdan  faylni yuklab olishni ko'ramiz
# !wget https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/USD_UZS.csv
# Out:
# --2022-10-19 12:50:27--  https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/USD_UZS.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2533 (2.5K) [text/plain]
# Saving to: ‘USD_UZS.csv’
#
# USD_UZS.csv         100%[===================>]   2.47K  --.-KB/s    in 0s
#
# 2022-10-19 12:50:28 (43.9 MB/s) - ‘USD_UZS.csv’ saved [2533/2533]

# %%
import pandas as pd
# faylni yuklab oldik endi faylni o'qimiz
df=pd.read_csv("USD_UZS.csv") # fayning  
df
# Out:
#          Date     Price      Open      High       Low Change %
# 0   1/11/2021  10795.00  10674.21  10795.00  10674.00    1.13%
# 1   1/10/2021  10674.21  10692.00  10712.05  10656.60   -0.17%
# 2    1/9/2021  10692.00  10670.00  10710.00  10630.00    0.21%
# 3    1/8/2021  10670.00  10642.43  10683.00  10600.00    0.26%
# 4    1/7/2021  10642.43  10591.00  10680.00  10580.00    0.49%
# 5    1/6/2021  10591.00  10568.21  10616.02  10520.15    0.22%
# 6    1/5/2021  10568.21  10523.00  10609.91  10492.55    0.43%
# 7    1/4/2021  10523.00  10485.66  10552.01  10464.90    0.36%
# 8    1/3/2021  10485.66  10525.50  10541.70  10447.86   -0.38%
# 9    1/2/2021  10525.50  10518.98  10554.34  10460.00    0.06%
# 10   1/1/2021  10518.98  10476.90  10528.77  10441.60    0.40%
# 11  1/12/2020  10476.90  10427.38  10486.00  10361.00    0.47%
# 12  1/11/2020  10427.38  10359.88  10427.38  10342.80    0.65%
# 13  1/10/2020  10359.88  10321.21  10375.00  10263.50    0.37%
# ...

# %%
# githubdan papkani yukalash
# !git clone https://github.com/anvarnarz/praktikum_datasets
# Out:
# fatal: destination path 'praktikum_datasets' already exists and is not an empty directory.

# %%
# papkani yuklab olik endi bu papkani ichidan faylni o'qishni ko'ramiz
# bunda faylgacha bo'lgan yo'lni ko'rsatishimiz kerak
df16=pd.read_csv("praktikum_datasets/global_earthquake.csv",sep=';',nrows=100)
df16
# Out:
#    Date,Time,Latitude,Longitude,Type,Depth,Depth Error,Depth Seismic Stations,Magnitude,Magnitude Type,Magnitude Error,Magnitude Seismic Stations,Azimuthal Gap,Horizontal Distance,Horizontal Error,Root Mean Square,ID,Source,Location Source,Magnitude Source,Status
# 0   01/02/1965,13:44:18,19.246,145.616,Earthquake,...
# 1   01/04/1965,11:29:49,1.863,127.352,Earthquake,8...
# 2   01/05/1965,18:05:58,-20.579,-173.972,Earthquak...
# 3   01/08/1965,18:49:43,-59.076,-23.557,Earthquake...
# 4   01/09/1965,13:32:50,11.938,126.427,Earthquake,...
# ..                                                ...
# 95  03/22/1965,02:44:49,-15.262,-173.254,Earthquak...
# 96  03/22/1965,22:56:27,-31.974,-71.573,Earthquake...
# 97  03/23/1965,23:54:05,-15.382,-173.194,Earthquak...
# 98  03/24/1965,22:42:12,8.418,126.553,Earthquake,5...
# 99  03/28/1965,13:23:01,55.26,161.904,Earthquake,4...
#
# [100 rows x 1 columns]
